# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mariyam Shaila**
# <br>
# Data Scientist

# %% [markdown]
# *I am interested in Data Science as I am passionate about finding the hidden treasures in the Data. To be a Data Scientist is my career goal.*

# %% [markdown]
# ### I would like to execute a mathematical operation with multiplication using codes. Lets have a look...

# %%
5*5
# Out:
# 25

# %% [markdown]
# | Employee | Age | Designation |
# |----------|-----|-------------|
# | 1. Mr. X | 35  |Data Scientist|
# | 2. Mr. Y | 38  |Statistician  |
# | 3. Mr. Z | 39  |Business Analyst/ ~~data Analyst~~|
#
#  - one
#  - two
#  - three
